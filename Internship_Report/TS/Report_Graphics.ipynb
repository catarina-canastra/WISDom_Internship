# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold
from sklearn.metrics import make_scorer
from sklearn.metrics import mean_squared_error

# %%
features = ["date","time","flow","anomaly"]
df = pd.read_csv('test_barreiro_1.csv', sep=';', names=features)
#holidays = pd.read_csv('holidays2018.csv',sep=';')

# %%
# Use seaborn style defaults and set the default figure size
#sns.set(rc={'figure.figsize':(11, 4)})

# %%
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

red_patch = mpatches.Patch(label='Historical Data')
plt.legend(handles=[red_patch])

plt.show()

# %%
# Change line width of lines in matplotlib
df['flow'].plot(linewidth=2).set_title('Time series Analysis')
plt.xlabel('Time')
plt.ylabel('Water Flow (m3-s)')
red_patch = mpatches.Patch(label='Historical Data')
plt.legend(handles=[red_patch])

# %%
plt.plot(df['time'],df['flow']).set_title('Time series Analysis')
plt.xlabel('Time')
plt.ylabel('Water Flow (m3-s)')
red_patch = mpatches.Patch(label='Historical Data')
plt.legend(handles=[red_patch])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-a2f09c1d453b> in <module>
# ----> 1 plt.plot(df['time'],df['flow']).set_title('Time series Analysis')
#       2 plt.xlabel('Time')
#       3 plt.ylabel('Water Flow (m3-s)')
#       4 red_patch = mpatches.Patch(label='Historical Data')
#       5 plt.legend(handles=[red_patch])
#
# AttributeError: 'list' object has no attribute 'set_title'

# %%
# train_data['timestamp'] = pd.to_datetime(train_data['hour'])
df['timestamp'] = df['time'].dt.hour * 3600 + \
              df['time'].dt.minute * 60 #+ \
              #train_data['timestamp'].dt.second

#test_data['timestamp'] = pd.to_datetime(test_data['hour'])
#test_data['timestamp'] = test_data['timestamp'].dt.hour * 3600 + \
 #             test_data['timestamp'].dt.minute * 60 + \
  #            test_data['timestamp'].dt.second
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-1ada050b1414> in <module>
#       1 # train_data['timestamp'] = pd.to_datetime(train_data['hour'])
# ----> 2 df['timestamp'] = df['time'].dt.hour * 3600 + \
#       3               df['time'].dt.minute * 60 #+ \
#       4               #train_data['timestamp'].dt.second
#       5
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5133             or name in self._accessors
#    5134         ):
# -> 5135             return object.__getattribute__(self, name)
#    5136         else:
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\Anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# ...

# %%
df['timestamp'] = pd.to_datetime(df['time'])

df['timestamp'] = df['timestamp'].dt.hour #* 3600 #+ \
             # df['timestamp'].dt.minute * 60 + \
             # df['timestamp'].dt.second

# %%
df
# Out:
#           date      time       flow  anomaly  timestamp
# 0   10/05/2018  00:07:30  15.713694        0          0
# 1   10/05/2018  00:22:30  14.460300        0          0
# 2   10/05/2018  00:37:30  14.975789        0          0
# 3   10/05/2018  00:52:30  14.658967        0          0
# 4   10/05/2018  01:07:30  11.786478        0          1
# ..         ...       ...        ...      ...        ...
# 91  10/05/2018  22:52:30  23.881589        0         22
# 92  10/05/2018  23:07:30  21.902367        0         23
# 93  10/05/2018  23:22:30  23.582700        0         23
# 94  10/05/2018  23:37:30  23.657244        0         23
# 95  10/05/2018  23:52:30  17.684200        0         23
#
# [96 rows x 5 columns]

# %%
# Change line width of lines in matplotlib
df['flow'].plot(linewidth=2).set_title('Time series Analysis')
plt.xlabel('Time')
plt.ylabel('Water Flow (m3-s)')
red_patch = mpatches.Patch(label='Historical Data')
plt.legend(handles=[red_patch])

# %%
df1=df.drop(columns=['anomaly', 'timestamp', 'date'])

# %%
df1
# Out:
#         time       flow
# 0   00:07:30  15.713694
# 1   00:22:30  14.460300
# 2   00:37:30  14.975789
# 3   00:52:30  14.658967
# 4   01:07:30  11.786478
# ..       ...        ...
# 91  22:52:30  23.881589
# 92  23:07:30  21.902367
# 93  23:22:30  23.582700
# 94  23:37:30  23.657244
# 95  23:52:30  17.684200
#
# [96 rows x 2 columns]

# %%
df1.plot()
plt.show()

# %%
# Change line width of lines in matplotlib
df['flow'].plot(linewidth=2).set_title('Time series Analysis')
plt.xticks([7,22,37,52,67]) # mudar escala do eixo X
plt.xlabel('Time')
plt.ylabel('Water Flow (m3-s)')
red_patch = mpatches.Patch(label='Historical Data')
plt.legend(handles=[red_patch])
