# %%
# Basics
import pandas as pd
import numpy as np
import time as tm
import math
# For Exploratory Data Analysis (EDA)
import seaborn as sns; sns.set()
# Alias for set_theme(), which is the preferred interface.
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.patches as mpatches

# %%
# Names of the columns
features = ["datetime","flow"]

df = pd.read_csv('TSAnalysis2.csv', sep = ',', names = features)

# %%
df
# Out:
#                 datetime       flow
# 0    2018-01-03 00:07:30  12.581431
# 1    2018-01-03 00:22:30  11.815181
# 2    2018-01-03 00:37:30  10.637583
# 3    2018-01-03 00:52:30   9.602417
# 4    2018-01-03 01:07:30   8.812417
# ..                   ...        ...
# 283  2018-01-05 22:52:30  16.706306
# 284  2018-01-05 23:07:30  15.249208
# 285  2018-01-05 23:22:30  14.508319
# 286  2018-01-05 23:37:30  14.530458
# 287  2018-01-05 23:52:30  14.284292
#
# [288 rows x 2 columns]

# %%
# The strftime() method returns a string representing date and time using date, time or datetime object
#df['datetime'] = pd.to_datetime(df['datetime'], dayfirst=True).dt.strftime('%Y-%m-%d %H:%M:%S').astype(str)
#df

# %%
# .info() function is used to get a concise summary of the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 288 entries, 0 to 287
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  288 non-null    object
#  1   flow      288 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 4.6+ KB

# %%
# Immutable ndarray-like of datetime64 data
# Represented internally as int64, and which can be boxed to Timestamp objects that are subclasses of datetime and carry metadata.
df['datetime'] = pd.DatetimeIndex(data=df['datetime'], dtype='datetime64[ns]', name='datetime', freq=None)

# %%
# Set the DataFrame index using existing columns
df = df.set_index('datetime')
# The index (row labels) of the DataFrame
df.index
# Out:
# DatetimeIndex(['2018-01-03 00:07:30', '2018-01-03 00:22:30',
#                '2018-01-03 00:37:30', '2018-01-03 00:52:30',
#                '2018-01-03 01:07:30', '2018-01-03 01:22:30',
#                '2018-01-03 01:37:30', '2018-01-03 01:52:30',
#                '2018-01-03 02:07:30', '2018-01-03 02:22:30',
#                ...
#                '2018-01-05 21:37:30', '2018-01-05 21:52:30',
#                '2018-01-05 22:07:30', '2018-01-05 22:22:30',
#                '2018-01-05 22:37:30', '2018-01-05 22:52:30',
#                '2018-01-05 23:07:30', '2018-01-05 23:22:30',
#                '2018-01-05 23:37:30', '2018-01-05 23:52:30'],
#               dtype='datetime64[ns]', name='datetime', length=288, freq=None)

# %%
df
# Out:
#                           flow
# datetime
# 2018-01-03 00:07:30  12.581431
# 2018-01-03 00:22:30  11.815181
# 2018-01-03 00:37:30  10.637583
# 2018-01-03 00:52:30   9.602417
# 2018-01-03 01:07:30   8.812417
# ...                        ...
# 2018-01-05 22:52:30  16.706306
# 2018-01-05 23:07:30  15.249208
# 2018-01-05 23:22:30  14.508319
# 2018-01-05 23:37:30  14.530458
# 2018-01-05 23:52:30  14.284292
#
# [288 rows x 1 columns]

# %%
# Use seaborn style defaults and set the default figure size
sns.set(rc={'figure.figsize':(7, 4)})

# %%
# Change line width of lines in matplotlib
df['flow'].plot(linewidth=2).set_title('Time Series Analysis')
plt.xlabel('Datetime (month-day hour)')
plt.ylabel('Flow rate ($m^3s^{-1}$)')
# Out:
# Text(0, 0.5, 'Flow rate ($m^3s^{-1}$)')

# %%
# Use seaborn style defaults and set the default figure size
sns.set(rc={'figure.figsize':(7, 4)})
# Change line width of lines in matplotlib
df['flow'].plot(linewidth=2).set_title('Time Series Analysis')
plt.xlabel('Datetime (month-day hour)')
plt.ylabel('Flow rate ($m^3s^{-1}$)')
red_patch = mpatches.Patch(label='Historical Data')
plt.legend(handles=[red_patch], loc="best")

# %%
# Use seaborn style defaults and set the default figure size
sns.set(rc={'figure.figsize':(7, 4)})
# Change line width of lines in matplotlib
df['flow'].plot(linewidth=2).set_title('Time Series Analysis')
plt.xlabel('Datetime (month-day hour)')
plt.ylabel('Flow rate ($m^3s^{-1}$)')
red_patch = mpatches.Patch(label='Historical' '\n Data')
plt.legend(handles=[red_patch], loc="lower right")

# %%
# Use seaborn style defaults and set the default figure size
sns.set(rc={'figure.figsize':(9, 4)})

# %%
ax = df.loc['2017-01-01','flow'].plot()
ax.set_title('Time Series Analysis')
ax.set_xlabel('Datetime')
ax.set_ylabel('Water Flow (m3-s)')
# Out:
# Text(0, 0.5, 'Water Flow (m3-s)')
