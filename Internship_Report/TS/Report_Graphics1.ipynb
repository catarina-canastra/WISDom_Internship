# %%
# Basics
import pandas as pd
import numpy as np
import time as tm
import math
# For Exploratory Data Analysis (EDA)
import seaborn as sns; sns.set()
# Alias for set_theme(), which is the preferred interface.
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Names of the columns
features = ["datetime","flow"]

df = pd.read_csv('TSAnalysis.csv', sep = ',', names = features)

# %%
df
# Out:
#                 datetime       flow
# 0    2017-01-01 00:07:30  70.000000
# 1    2017-01-01 01:07:30  81.469722
# 2    2017-01-01 02:07:30  39.924333
# 3    2017-01-01 03:07:30  49.727556
# 4    2017-01-01 04:07:30  54.967167
# ..                   ...        ...
# 118  2017-01-05 19:07:30  67.101667
# 119  2017-01-05 20:07:30  49.456611
# 120  2017-01-05 21:07:30  51.662778
# 121  2017-01-05 22:07:30  46.803444
# 122  2017-01-05 23:07:30  48.355500
#
# [123 rows x 2 columns]

# %%
# The strftime() method returns a string representing date and time using date, time or datetime object
#df['datetime'] = pd.to_datetime(df['datetime'], dayfirst=True).dt.strftime('%Y-%m-%d %H:%M:%S').astype(str)
#df

# %%
# .info() function is used to get a concise summary of the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123 entries, 0 to 122
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  123 non-null    object
#  1   flow      123 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 2.0+ KB

# %%
# Immutable ndarray-like of datetime64 data
# Represented internally as int64, and which can be boxed to Timestamp objects that are subclasses of datetime and carry metadata.
df['datetime'] = pd.DatetimeIndex(data=df['datetime'], dtype='datetime64[ns]', name='datetime', freq=None)

# %%
# Set the DataFrame index using existing columns
df = df.set_index('datetime')
# The index (row labels) of the DataFrame
df.index
# Out:
# DatetimeIndex(['2017-01-01 00:07:30', '2017-01-01 01:07:30',
#                '2017-01-01 02:07:30', '2017-01-01 03:07:30',
#                '2017-01-01 04:07:30', '2017-01-01 05:07:30',
#                '2017-01-01 06:07:30', '2017-01-01 07:07:30',
#                '2017-01-01 08:07:30', '2017-01-01 09:07:30',
#                ...
#                '2017-01-05 14:07:30', '2017-01-05 15:07:30',
#                '2017-01-05 16:07:30', '2017-01-05 17:07:30',
#                '2017-01-05 18:07:30', '2017-01-05 19:07:30',
#                '2017-01-05 20:07:30', '2017-01-05 21:07:30',
#                '2017-01-05 22:07:30', '2017-01-05 23:07:30'],
#               dtype='datetime64[ns]', name='datetime', length=123, freq=None)

# %%
df
# Out:
#                           flow
# datetime
# 2017-01-01 00:07:30  70.000000
# 2017-01-01 01:07:30  81.469722
# 2017-01-01 02:07:30  39.924333
# 2017-01-01 03:07:30  49.727556
# 2017-01-01 04:07:30  54.967167
# ...                        ...
# 2017-01-05 19:07:30  67.101667
# 2017-01-05 20:07:30  49.456611
# 2017-01-05 21:07:30  51.662778
# 2017-01-05 22:07:30  46.803444
# 2017-01-05 23:07:30  48.355500
#
# [123 rows x 1 columns]

# %%
# Use seaborn style defaults and set the default figure size
sns.set(rc={'figure.figsize':(11, 4)})

# %%
# Change line width of lines in matplotlib
df['flow'].plot(linewidth=2).set_title('Time Series Analysis')
plt.xlabel('Date (day)')
plt.ylabel('Water Flow (m3-s)')
# Out:
# Text(0, 0.5, 'Water Flow (m3-s)')

# %%
# Use seaborn style defaults and set the default figure size
sns.set(rc={'figure.figsize':(9, 4)})

# %%
ax = df.loc['2017-01-01','flow'].plot()
ax.set_title('Time Series Analysis')
ax.set_xlabel('Datetime')
ax.set_ylabel('Water Flow (m3-s)')
# Out:
# Text(0, 0.5, 'Water Flow (m3-s)')
