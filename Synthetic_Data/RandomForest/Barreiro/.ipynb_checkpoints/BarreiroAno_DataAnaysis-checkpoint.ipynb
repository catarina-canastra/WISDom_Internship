# %% [markdown]
# # Learning Univariate Time-Series, in the context of the WISDom project

# %% [markdown]
# ## Start

# %% [markdown]
# ### Import necessary libraries

# %%
# Basics
import pandas as pd
import numpy as np
import time as tm
import math
# For Exploratory Data Analysis (EDA)
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
# For data preprocessing/data transformation
from sklearn.preprocessing import StandardScaler


# For the algorithm implementation



# For evaluation metrics
from sklearn.metrics import precision_score


# To determinate the best parameters

# %% [markdown]
# ### Load datasets

# %%
column_names = ["date", "time", "value", "detection"]

barreiro_ano = pd.read_csv('C:/Users/Catarina/Documents/WISDom_Internship/WISDom_InternshipCode/WISDom_Internship/Learning_TimeSeries/Barreiro/barreiro_ano.csv', sep = ';', names = column_names)
# train_barreiro 1,2,3,4
# test_barreiro 1,2,3,4
# holidays

# %% [markdown]
# #### Visualize data

# %%
pd.set_option('display.max_rows', 100)

# %%
barreiro_ano.head(100)
# Out:
#           date      time      value  detection
# 0   01/01/2018  00:07:30  18.333067          0
# 1   01/01/2018  00:22:30  18.333067          0
# 2   01/01/2018  00:37:30  19.784872          0
# 3   01/01/2018  00:52:30  22.294744          0
# 4   01/01/2018  01:07:30  27.229756          0
# 5   01/01/2018  01:22:30  27.615883          0
# 6   01/01/2018  01:37:30  26.663889          0
# 7   01/01/2018  01:52:30  24.244111          0
# 8   01/01/2018  02:07:30  22.159583          0
# 9   01/01/2018  02:22:30  18.577917          0
# 10  01/01/2018  02:37:30  21.033250          0
# 11  01/01/2018  02:52:30  21.764244          0
# 12  01/01/2018  03:07:30  16.676861          0
# 13  01/01/2018  03:22:30  19.641456          0
# 14  01/01/2018  03:37:30  18.404778          0
# 15  01/01/2018  03:52:30  14.274144          0
# 16  01/01/2018  04:07:30  14.929328          0
# 17  01/01/2018  04:22:30  13.771383          0
# 18  01/01/2018  04:37:30  12.257361          0
# 19  01/01/2018  04:52:30  11.547061          0
# 20  01/01/2018  05:07:30  18.924483          0
# 21  01/01/2018  05:22:30  25.860844          0
# 22  01/01/2018  05:37:30  28.645564          0
# 23  01/01/2018  05:52:30  22.815256          0
# 24  01/01/2018  06:07:30  16.732894          0
# 25  01/01/2018  06:22:30  11.912972          0
# 26  01/01/2018  06:37:30  17.110244          0
# 27  01/01/2018  06:52:30  16.436706          0
# 28  01/01/2018  07:07:30  12.103372          0
# 29  01/01/2018  07:22:30  15.571689          0
# 30  01/01/2018  07:37:30  15.850794          0
# 31  01/01/2018  07:52:30  12.696561          0
# 32  01/01/2018  08:07:30  15.739394          0
# 33  01/01/2018  08:22:30  17.447878          0
# 34  01/01/2018  08:37:30  17.324889          0
# 35  01/01/2018  08:52:30  19.821306          0
# 36  01/01/2018  09:07:30  20.762122          0
# 37  01/01/2018  09:22:30  23.702389          0
# 38  01/01/2018  09:37:30  25.091006          0
# 39  01/01/2018  09:52:30  26.392150          0
# 40  01/01/2018  10:07:30  32.499356          0
# ## Dataset info

# %% [markdown]
# #### Features

# %%
# Names of columns
print('Feature Names')
print(barreiro_ano.columns)
# Out:
# Feature Names
# Index(['date', 'time', 'value', 'detection'], dtype='object')

# %% [markdown]
# #### Data dimension

# %%
print('Data Dimension:')
print('Number of Records:', barreiro_ano.shape[0])
print('Number of Features:', barreiro_ano.shape[1])
# Out:
# Data Dimension:
# Number of Records: 35040
# Number of Features: 4

# %% [markdown]
# #### Shape

# %%
barreiro_ano.shape
# Out:
# (35040, 4)

# %% [markdown]
# #### Info (types)

# %%
# Understand the data type of each feature
# .info() to get a concise summary of the dataframe
barreiro_ano.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35040 entries, 0 to 35039
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       35040 non-null  object
#  1   time       35040 non-null  object
#  2   value      35040 non-null  float64
#  3   detection  35040 non-null  int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 1.1+ MB

# %% [markdown]
# #### Missing values

# %%
# Discover how many data is missing
missing = barreiro_ano.isnull().sum()

print(missing)
# Out:
# date         0
# time         0
# value        0
# detection    0
# dtype: int64

# %%
# Per summary there aren't null values

# %% [markdown]
# #### Describe

# %%
# Descriptive statistics include those that summarize the central tendency, dispersion and shape of a dataset distribution, excluding NaN values
barreiro_ano.describe()
# Out:
#               value     detection
# count  35040.000000  35040.000000
# mean      34.297686      0.002426
# std       18.234363      0.049193
# min        3.416723      0.000000
# 25%       21.773553      0.000000
# 50%       30.735589      0.000000
# 75%       44.598200      0.000000
# max      131.778461      1.000000

# %% [markdown]
# ### Skewnes

# %%
# The skewness for a normal distribution is zero, and any symmetric data
# should have a skewness near zero.
# Negative values for the skewness indicate data that are skewed left and positive values for the
# skewness indicate data that are skewed right.
# By skewed left, it means that the left tail is long relative to the right tail.
# Similarly, skewed right means that the right tail is long relative to the left tail.

# %%
print('Skewness of the below features:')
print(barreiro_ano.skew())
# Out:
# Skewness of the below features:
# value         0.894086
# detection    20.230491
# dtype: float64

# %%
# Graph view
skew = barreiro_ano.skew()
skew_df = pd.DataFrame(skew, index = None, columns = ['Skewness'])
plt.figure(figsize=(15,7))
sns.barplot(x = skew_df.index, y = 'Skewness', data = skew_df)
plt.xticks(rotation = 90)
# Out:
# (array([0, 1]), <a list of 2 Text major ticklabel objects>)

# %%
barreiro_ano['month' = pd.to_datetime]

# %% [markdown]
# -------------------------------- " --------------------------------

# %% [markdown]
# #### Ver se o pandas está a lidar com a coluna DATE como objetos simples ou tipo de dados Datetime integrado do pandas

# %%
barreiro_ano.date
# Out:
# 0        01/01/2018
# 1        01/01/2018
# 2        01/01/2018
# 3        01/01/2018
# 4        01/01/2018
#             ...
# 35035    31/12/2018
# 35036    31/12/2018
# 35037    31/12/2018
# 35038    31/12/2018
# 35039    31/12/2018
# Name: date, Length: 35040, dtype: object

# %% [markdown]
# #### Como está a lidar como objetos simples, é necessário converter para Datetime

# %%
barreiro_ano.date = pd.to_datetime(barreiro_ano.date)

# %% [markdown]
# #### Atribuir DATE como coluna index

# %% [markdown]
# ### Outliers (bursts/leakages/anomalys/events)
