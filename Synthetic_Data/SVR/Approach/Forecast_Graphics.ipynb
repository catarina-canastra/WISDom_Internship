# %%
# %run SVR_RB_20210531.ipynb
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Documents\WISDomIntership\SVR_RB_20210531.ipynb in <module>
#       5     return np.average(series[-n:])
#       6
# ----> 7 moving_average(df, 24) # prediction for the last observed day (past 24 hours)
#
# ~\Documents\WISDomIntership\SVR_RB_20210531.ipynb in moving_average(series, n)
#       3         Calculate average of last n observations
#       4     """
# ----> 5     return np.average(series[-n:])
#       6
#       7 moving_average(df, 24) # prediction for the last observed day (past 24 hours)
#
# <__array_function__ internals> in average(*args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\numpy\lib\function_base.py in average(a, axis, weights, returned)
#     378
#     379     if weights is None:
# --> 380         avg = a.mean(axis)
#     381         scl = avg.dtype.type(a.size/avg.size)
#     382     else:
#
# ...

# %%
def new_graphic(y_true, y_pred, day):
    yTrue=[]
    yPred=[]
    if day==1:
        yTrue=y_true[0:periods_per_day] # to look at 1 day
        yPred=y_pred[0:periods_per_day]
    else:
        yTrue=y_true[0:periods_per_day*day]
        yPred=y_pred[0:periods_per_day*day]
        
    plt.scatter(y_true, y_pred, color = 'magenta')
    plt.plot(y_pred, color = 'green')
    plt.title('Truth or Bluff (Support Vector Regression Model)')
    plt.xlabel('Position level')
    plt.ylabel('Salary')
    plt.show()

# %%
pred_1d=new_graphic(y_true, y_pred, 1)

# %%
def new_graphic(y_true, y_pred, day):
    yTrue=[]
    yPred=[]
    if day==1:
        yTrue=y_true[0:periods_per_day] # to look at 1 day
        yPred=y_pred[0:periods_per_day]
    else:
        yTrue=y_true[0:periods_per_day*day]
        yPred=y_pred[0:periods_per_day*day]

    plt.plot(y_true, y_pred, c='g', label='Linear model')

# %%
pred_1d=new_graphic(y_true, y_pred, 1)
